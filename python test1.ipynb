# %% [markdown]
# 1.what is python?what are the benefits of python?
#
#   python:
#  python is a hihg level programming language.It is introduced by guido van russel in 1995.it is easier programming        language.compared to all other languages it is very easy and east to learn.
#  benefits of python:
# - it used to web development
# - its take low memory
# - it is used in data science and artificial intilligence
# - it is simple program writing
# -
# 2.what are the lists and tuple?what is the key difference b/w the two?
#
#   lists:
#  lists is known as collection of elements in order.
#  tuples:
#  tuples is known as this is the data type represents by immutable sequence of elements.
#  key difference:
#  lists is mutable.
#  tuples is immutable.
#
# 3.what is the difference b/w a mutable data type and an immutable data type?
#
#   mutable data type is known as we can change,update and replace the elements.
#  immutable data type is known as we can not change,update and replace the elements.
#
# 4.what is the difference b/w set and dictionary?
#
#   dictionary is known as collection key value pairs.
#  set is known as collection of unique elements.
#
# 5.what is the difference b/w /and // in python?
#
#  / it used to division and // is used to floor division. // it remove float value.
#
# 6.how do you comment on a single line and multiple lines in python?
#
#   to describe the program or unnderstand to the user.# is uses in comments.
#
# 7.how does python dictionary different form a list?
#
#   dictionary is konwn as collection key value pairs and list is a collection of elements both are different.
#
# 8.how do i modify a string in python?
#
#   replace() method.
#
# 9.what is index in python and its types?
#
#   accessing specific element from a data
#  index types:positive,negative.
#
# 10.what is negative index in python?
#
#    negative index start from right to left.its stats from -1,-2,-3,etc.
#
# 11.what is the slicing in python?
#
#    accessing particulatr group of elements in a data.
#
# 12.what are the keywords in python?
#
#    keywords is known as reserverd words or special words.its not used as variables.total keywords 35 like if,else,for,etc.
#
# 13.what are the variables in python?
#
#    variables are known as to store the elements,values,data.
#
# 14.explain the rules of creating variables?
#
#   - variables are alphanumaricals
#   - variables are can't start with digits
#   - variables are can't start with special characters excpet -
#   - can't take keywords as the variable
#   - it is case sensitivs.
#   -
# 15.what are the operators in python?
#
#    operator is known to perform a operation in operands.these are 7
#  - arthimetical
#  - assignment
#  - logical
#  - comparison
#  - identity
#  - membership
#  - bitwise.
#
# 16.explain about logical operators with examples?
#
#    logical operators is used to check whether the expression is true or false.these are 3
#  - logical and
#  a(3<5 and 5>2)
#  - logical or
#  b(3<5 or 2<1)
#  - logical not
#  not(3<5 and 5>2).
#
# 17.how do you write comments in python?
#
#    used atrt of # to write comments in python.
#
# 18.how will you capatalize the first letter of string?
#
#    upper()method.
#
# 19.how will covert string to all lower case?
#
#    lower()method.
#
# 20.how to comment multiple lines in python?
#
#    using # in start of the comment.
#
# 21.what does len() do and explain with example?
#
#    len() to calculate the lenth of a string
#    example:
#    a='apple'
#    len(a)
#    ->5.
#
# 22.how to remove values from a python list?
#
#    pop()method.
#
# 23.what is splilt used for?
#
#    split is used for to convert string to list format.
